# %%
# %pylab inline
from itertools import combinations
import pandas as pd
import ipm
import scatter
mpl.rcParams['font.size'] = 16

#This is some sample metadata from the LQ92 XPP run
inFN = 'metadata.csv'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/kevin/opt/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['scatter']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
M = pd.read_csv(inFN)


#Split the channels into separate columns with the proper dtype
M['ipm2_0'] = [float(i.split(',')[0]) for i in M['ipm2_channels']]
M['ipm2_1'] = [float(i.split(',')[1]) for i in M['ipm2_channels']]
M['ipm2_2'] = [float(i.split(',')[2]) for i in M['ipm2_channels']]
M['ipm2_3'] = [float(i.split(',')[3]) for i in M['ipm2_channels']]

M['ipm3_0'] = [float(i.split(',')[0]) for i in M['ipm3_channels']]
M['ipm3_1'] = [float(i.split(',')[1]) for i in M['ipm3_channels']]
M['ipm3_2'] = [float(i.split(',')[2]) for i in M['ipm3_channels']]
M['ipm3_3'] = [float(i.split(',')[3]) for i in M['ipm3_channels']]

del M['ipm2_channels']
del M['ipm3_channels']

M
# Out:
#        Unnamed: 0      filename      ipm2      ipm3  ipm2_xpos  ipm2_ypos  \
# 0               0  1_00001.tiff  0.851310  0.586469  -0.016900   0.125221
# 1               1  2_00001.tiff  0.469148  0.327600  -0.025254   0.138201
# 2               2  3_00001.tiff  0.418488  0.287545  -0.019781   0.120668
# 3               3  4_00001.tiff  0.235303  0.164481  -0.022372   0.133481
# 4               4  1_00002.tiff  0.698796  0.482403  -0.021384   0.137786
# 5               5  2_00002.tiff  0.527895  0.364755  -0.009291   0.130393
# 6               6  3_00002.tiff  0.382934  0.263283  -0.012549   0.126886
# 7               7  4_00002.tiff  0.018320  0.012882   0.058618   0.289906
# 8               8  1_00003.tiff  0.840705  0.580594  -0.024424   0.125937
# 9               9  2_00003.tiff  0.221799  0.154791  -0.019069   0.145193
# 10             10  3_00003.tiff  0.172360  0.118475  -0.023562   0.092117
# 11             11  4_00003.tiff  0.173352  0.117636  -0.008766   0.099041
# ...

# %%
labels = {
    'ipm2_0': r"$IPM2_0$", 
    'ipm2_1': r"$IPM2_1$", 
    'ipm2_2': r"$IPM2_2$", 
    'ipm2_3': r"$IPM2_3$",
}

for i,j in combinations(labels, 2):
    x,y = np.array(M[i]), np.array(M[j])
    f = plt.figure(figsize=(10,10))
    plt.scatter(x, y, facecolors='none', edgecolors='k', alpha=0.05)
    plt.xlabel(labels[i])
    plt.ylabel(labels[j])
    #plt.savefig("{}-{}".format(labels[i][1:-1], labels[j][1:-1]), fmt='png')

# %%
from itertools import combinations
import cvxpy as cvx

labels = {
    'ipm2_0': r"$IPM2_0$", 
    'ipm2_1': r"$IPM2_1$", 
    'ipm2_2': r"$IPM2_2$", 
    'ipm2_3': r"$IPM2_3$",
}

for i,j in combinations(labels, 2):
    x,y = np.array(M[i]), np.array(M[j])
    m,b = cvx.Variable(2)
    r = m*x + b - y
    p = cvx.Problem(cvx.Minimize(cvx.sum_squares(r)))
    p.solve(solver='SCS')
    
    
    f = plt.figure(figsize=(10,5))
    ax = f.add_subplot(121)
    plt.scatter(x, y, facecolors='none', edgecolors='k', alpha=0.05)
    plt.xlabel(labels[i])
    plt.ylabel(labels[j])
    ax = f.add_subplot(122)

    hist(r.value, 100, color='k')
    plt.title("MSE={}".format(np.mean(np.square(r.value))))

# %%
#Let's simply double check that we understand how the xpos and ypos calculations work for ipm2/3

f = plt.figure(figsize=(12, 5))
f.add_subplot(121)
xpos = (M['ipm2_1'] - M['ipm2_3']) / (M['ipm2_1'] + M['ipm2_3'])
plt.scatter(M['ipm2_xpos'], xpos, facecolors='none', edgecolors='k')
plt.xlabel(r"$IPM2\ X_{pos}\ (PSANA)$")
plt.ylabel(r"$\frac{IPM2_1 - IPM2_3} {IPM2_1 + IPM2_3}$")
xlim,ylim = plt.xlim(),plt.ylim()
lim = (max(xlim[0], ylim[0]), max(xlim[1], ylim[1]))
plt.plot(np.linspace(lim[0], lim[1], 1000), np.linspace(lim[0], lim[1], 1000), '--r')
plt.xlim(xlim)
plt.ylim(ylim)
ax = f.add_subplot(122)
plt.hist(xpos - M['ipm2_xpos'], 100, color='k')
plt.xlabel("Residuals")
plt.xticks(rotation=45)
ax.yaxis.tick_right()

f = plt.figure(figsize=(12, 5))
f.add_subplot(121)
ypos = (M['ipm2_0'] - M['ipm2_2']) / (M['ipm2_0'] + M['ipm2_2'])
plt.scatter(M['ipm2_ypos'], ypos, facecolors='none', edgecolors='k')
plt.xlabel(r"$IPM2\ Y_{pos}\ (PSANA)$")
plt.ylabel(r"$\frac{IPM2_0 - IPM2_2} {IPM2_0 + IPM2_2}$")
xlim,ylim = plt.xlim(),plt.ylim()
lim = (max(xlim[0], ylim[0]), max(xlim[1], ylim[1]))
plt.plot(np.linspace(lim[0], lim[1], 1000), np.linspace(lim[0], lim[1], 1000), '--r')
plt.xlim(xlim)
plt.ylim(ylim)
ax = f.add_subplot(122)
plt.hist(ypos - M['ipm2_ypos'], 100, color='k')
plt.xlabel("Residuals")
plt.xticks(rotation=45)
ax.yaxis.tick_right()



f = plt.figure(figsize=(12, 5))
f.add_subplot(121)
xpos = (M['ipm3_1'] - M['ipm3_3']) / (M['ipm3_1'] + M['ipm3_3'])
plt.scatter(M['ipm3_xpos'], xpos, facecolors='none', edgecolors='k')
plt.xlabel(r"$IPM3\ X_{pos}\ (PSANA)$")
plt.ylabel(r"$\frac{IPM3_1 - IPM3_3} {IPM3_1 + IPM3_3}$")
xlim,ylim = plt.xlim(),plt.ylim()
lim = (max(xlim[0], ylim[0]), max(xlim[1], ylim[1]))
plt.plot(np.linspace(lim[0], lim[1], 1000), np.linspace(lim[0], lim[1], 1000), '--r')
plt.xlim(xlim)
plt.ylim(ylim)
ax = f.add_subplot(122)
plt.hist(xpos - M['ipm3_xpos'], 100, color='k')
plt.xlabel("Residuals")
plt.xticks(rotation=45)
ax.yaxis.tick_right()

f = plt.figure(figsize=(12, 5))
f.add_subplot(121)
ypos = (M['ipm3_0'] - M['ipm3_2']) / (M['ipm3_0'] + M['ipm3_2'])
plt.scatter(M['ipm3_ypos'], ypos, facecolors='none', edgecolors='k')
plt.xlabel(r"$IPM3\ Y_{pos}\ (PSANA)$")
plt.ylabel(r"$\frac{IPM3_0 - IPM3_2} {IPM3_0 + IPM2_2}$")
xlim,ylim = plt.xlim(),plt.ylim()
lim = (max(xlim[0], ylim[0]), max(xlim[1], ylim[1]))
plt.plot(np.linspace(lim[0], lim[1], 1000), np.linspace(lim[0], lim[1], 1000), '--r')
plt.xlim(xlim)
plt.ylim(ylim)
ax = f.add_subplot(122)
plt.hist(ypos - M['ipm2_ypos'], 100, color='k')
plt.xlabel("Residuals")
plt.xticks(rotation=45)
ax.yaxis.tick_right()

# %%
#IPM Horizontal Panels have systematically larger readings
plt.figure(figsize=(10,10))
plt.title(r"IPM2 Intensity Distribution per Panel")
data  = [M['ipm2_0'], M['ipm2_1'], M['ipm2_2'], M['ipm2_3']]
parts = plt.violinplot(data, showmeans=False, showmedians=False, showextrema=False)

for pc in parts['bodies']:
    pc.set_facecolor("grey")
    pc.set_edgecolor("k")
    pc.set_alpha(1)

quartile1, medians, quartile3 = np.percentile(data, [25, 50, 75], axis=1)
whiskersMin, whiskersMax = np.min(data, axis=1),np.max(data, axis=1)

inds = np.arange(1, len(medians) + 1)
plt.scatter(inds, medians, marker='o', color='white', s=30, zorder=3)
plt.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
plt.vlines(inds, whiskersMin, whiskersMax, color='k', linestyle='-', lw=1)

plt.xticks([1,2,3,4], ['$IPM2_0$','$IPM2_1$','$IPM2_2$','$IPM2_3$'])


plt.figure(figsize=(10,10))
plt.title(r"IPM3 Intensity Distribution per Panel")
data  = [M['ipm3_0'], M['ipm3_1'], M['ipm3_2'], M['ipm3_3']]
parts = plt.violinplot(data, showmeans=False, showmedians=False, showextrema=False)


for pc in parts['bodies']:
    pc.set_facecolor("grey")
    pc.set_edgecolor("k")
    pc.set_alpha(1)

quartile1, medians, quartile3 = np.percentile(data, [25, 50, 75], axis=1)
whiskersMin, whiskersMax = np.min(data, axis=1),np.max(data, axis=1)

inds = np.arange(1, len(medians) + 1)
plt.scatter(inds, medians, marker='o', color='white', s=30, zorder=3)
plt.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
plt.vlines(inds, whiskersMin, whiskersMax, color='k', linestyle='-', lw=1)

plt.xticks([1,2,3,4], ['$IPM3_0$','$IPM3_1$','$IPM3_2$','$IPM3_3$'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f99089bd9b0>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
plt.figure(figsize=(10,5))
plt.title(r"IPM2 Position Distribution")
v = plt.hist(M['ipm2_xpos'], 200, color='k')
plt.xlabel(r'$X_{pos}$')
plt.xlim((-0.25, 0.25))

plt.figure(figsize=(10,5))
plt.title(r"IPM2 Position Distribution")
v = plt.hist(M['ipm2_ypos'], 200, color='k')
plt.xlabel(r'$Y_{pos}$')
plt.xlim((-0.25, 0.25))


print("""
X std = {}
Y std = {}
""".format(np.std(M['ipm2_xpos']), np.std(M['ipm2_ypos'])))
# Out:
# X std = 0.0389540284908522
# Y std = 0.10272762990455472

# %%
plt.figure()
D = (M['ipm2_0']+ M['ipm2_2']) / (M['ipm2_1'] + M['ipm2_3'])
plt.hist((M['ipm2_0']+ M['ipm2_2']) / (M['ipm2_1'] + M['ipm2_3']), 100, color='k')
plt.xlabel(r"$\frac {IPM2_0+IPM2_2}{IPM2_1+IPM2_3}$")
plt.ylabel('Observations')
plt.semilogy()
ymin,ymax = plt.ylim()
plt.ylim(ymin, ymax)
plt.vlines(np.median(D), ymin, ymax, 'r', '--')
plt.legend(['Median ({:0.2f})'.format(np.median(D))])

plt.figure()
D = (M['ipm3_0']+ M['ipm3_2']) / (M['ipm3_1'] + M['ipm3_3'])
plt.hist((M['ipm3_0']+ M['ipm3_2']) / (M['ipm3_1'] + M['ipm3_3']), 100, color='k')
plt.xlabel(r"$\frac {IPM3_0+IPM3_2}{IPM3_1+IPM3_3}$")
plt.ylabel('Observations')
plt.semilogy()
ymin,ymax = plt.ylim()
plt.ylim(ymin, ymax)
plt.vlines(np.median(D), ymin, ymax, 'r', '--')
plt.legend(['Median ({:0.2f})'.format(np.median(D))])

# %%
from importlib import reload
reload(ipm)
reload(scatter)
reload(ipm.scatter)

n = 100
xstd = 2000.
ystd = 2000.
points = 100
ko = 10000.
xpos,ypos = np.random.normal(0., xstd, n),np.random.normal(0., ystd, n)
r = 1e28*np.vstack([ipm.ipm_readings(ko, x, y, points=points) for x,y in zip(xpos,ypos)])

data = r.copy()

print(r)

#IPM Horizontal Panels have systematically larger readings
plt.figure(figsize=(10,10))
plt.title(r"Scattering Cross Section Distribution per Panel")
parts = plt.violinplot(data, showmeans=False, showmedians=False, showextrema=False)
plt.xticks([1,2,3,4], [r"$IPM_T$", r"$IPM_R$", r"$IPM_B$", r"$IPM_L$"])
plt.ylabel("barns")

for pc in parts['bodies']:
    pc.set_facecolor("grey")
    pc.set_edgecolor("k")
    pc.set_alpha(1)

quartile1, medians, quartile3 = np.percentile(data, [25, 50, 75], axis=0)
whiskersMin, whiskersMax = np.min(data, axis=0),np.max(data, axis=0)

inds = np.arange(1, len(medians) + 1)

plt.scatter(inds, medians, marker='o', color='white', s=30, zorder=3)
plt.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
plt.vlines(inds, whiskersMin, whiskersMax, color='k', linestyle='-', lw=1)

plt.figure()
xcalc = (r[:,1] - r[:,3]) / (r[:,1] + r[:,3])
plt.scatter(xpos, xcalc, facecolors='none', edgecolors='k')
plt.ylabel(r"$\frac{IPM_R - IPM_L}{IPM_R + IPM_L}$")
plt.xlabel(r"$X_{pos}\ \mu m$")

plt.figure()
ycalc = (r[:,0] - r[:,2]) / (r[:,0] + r[:,2])
plt.scatter(ypos, ycalc, facecolors='none', edgecolors='k')
plt.ylabel(r"$\frac{IPM_T - IPM_B}{IPM_T + IPM_B}$")
plt.xlabel(r"$Y_{pos}\ \mu m$")


plt.figure()
plt.scatter(r[:,0], r[:,2], edgecolors="k", facecolors='none')
plt.xlabel(r"$IPM_T$")
plt.ylabel(r"$IPM_B$")
plt.figure()
plt.scatter(r[:,1], r[:,3], edgecolors="k", facecolors='none')
plt.xlabel(r"$IPM_R$")
plt.ylabel(r"$IPM_L$")
# Out:
# [[5.10762177 3.13138638 5.1246459  3.12879475]
#  [5.10442119 3.12906155 5.12622944 3.12875808]
#  [5.10258813 3.12775101 5.12716089 3.12989213]
#  [5.10971098 3.13008451 5.11779101 3.12985244]
#  [5.12373268 3.1287301  5.10695419 3.12910804]
#  [5.10934012 3.12979827 5.12359265 3.12876475]
#  [5.10187816 3.12975527 5.12878    3.12807986]
#  [5.1089533  3.13020287 5.12011545 3.12982626]
#  [5.12174665 3.12885497 5.10975804 3.13029108]
#  [5.11917778 3.1308488  5.11010589 3.12906049]
#  [5.10886767 3.13019999 5.1202078  3.12982712]
#  [5.11304287 3.12740839 5.11873456 3.13021949]
#  [5.10743709 3.13093229 5.1201377  3.12768427]
#  [5.11507178 3.12923228 5.11236716 3.13140775]
#  [5.10555765 3.12706288 5.12503158 3.1298331 ]
#  [5.11111558 3.12856047 5.11707262 3.13066063]
#  [5.11309722 3.13143519 5.11871593 3.12799321]
#  [5.08844645 3.1289698  5.13946406 3.12728463]
#  [5.11586734 3.13131985 5.11570336 3.12785204]
#  [5.10717375 3.13055234 5.12505052 3.12817508]
# ...

# %%
xpos,ypos = 0., 0.
zmin,zmax = 0.,1.0
norm = mpl.colors.Normalize(zmin, zmax)

e = 10000.
f = plt.figure(figsize=(10, 7))

l = -10000.
si = ipm.differential_scattering(e, l=l, Z=14, xpos=xpos, ypos=ypos) 
n  = ipm.differential_scattering(e, l=l, Z=7, xpos=xpos, ypos=ypos) 
readings = {k:(3.*si[k] + 4.*n[k])/7. for k in si}
f.suptitle(r"$|k_o|={}keV$".format(int(e/1000.)))
ax = f.add_subplot(111)
ax = ipm.plot_detector(readings, ax=ax, norm=norm, xpos=xpos, ypos=ypos)
ax.set_title("Differential Scattering Cross-section")
# Out:
# Text(0.5,1,'Differential Scattering Cross-section')

# %%
from importlib import reload
reload(ipm)
reload(ipm.scatter)

xpos,ypos = 0., 2000.
zmin,zmax = 0.,1.0
norm = mpl.colors.Normalize(zmin, zmax)

e = 1000.
f = plt.figure(figsize=(17, 7))

l = -10000.
si = ipm.differential_scattering(e, l=l, Z=14, xpos=xpos, ypos=ypos) 
n  = ipm.differential_scattering(e, l=l, Z=7, xpos=xpos, ypos=ypos) 
readings = {k:(3.*si[k] + 4.*n[k])/7. for k in si}
f.suptitle(r"$|k_o|={}keV$".format(int(e/1000.)))
ax = f.add_subplot(121)
ax = ipm.plot_detector(readings, ax=ax, norm=norm, xpos=xpos, ypos=ypos)
ax.set_title("Backscatter")

l = 10000.
si = ipm.differential_scattering(e, l=l, Z=14, xpos=xpos, ypos=ypos) 
n  = ipm.differential_scattering(e, l=l, Z=7, xpos=xpos, ypos=ypos) 
readings = {k:(3.*si[k] + 4.*n[k])/7. for k in si}
ax = f.add_subplot(122)
e = 10000
ax = ipm.plot_detector(readings, ax=ax, norm=norm, xpos=xpos, ypos=ypos)
ax.set_title("Forward Scatter")
plt.tight_layout()

e = 10000.
f = plt.figure(figsize=(17, 7))

l = -10000.
si = ipm.differential_scattering(e, l=l, Z=14, xpos=xpos, ypos=ypos) 
n  = ipm.differential_scattering(e, l=l, Z=7, xpos=xpos, ypos=ypos) 
readings = {k:(3.*si[k] + 4.*n[k])/7. for k in si}
f.suptitle(r"$|k_o|={}keV$".format(int(e/1000.)))
ax = f.add_subplot(121)
ax = ipm.plot_detector(readings, ax=ax, norm=norm, xpos=xpos, ypos=ypos)
ax.set_title("Backscatter")

l = 10000.
si = ipm.differential_scattering(e, l=l, Z=14, xpos=xpos, ypos=ypos) 
n  = ipm.differential_scattering(e, l=l, Z=7, xpos=xpos, ypos=ypos) 
readings = {k:(3.*si[k] + 4.*n[k])/7. for k in si}
ax = f.add_subplot(122)
e = 10000
ax = ipm.plot_detector(readings, ax=ax, norm=norm, xpos=xpos, ypos=ypos)
ax.set_title("Forward Scatter")
plt.tight_layout()

# %%
r = r*1e28
plt.figure()
plt.scatter(r[:,0], r[:,2], edgecolors="k", facecolors='none')
plt.xlabel(r"$IPM_T$")
plt.ylabel(r"$IPM_B$")
plt.figure()
plt.scatter(r[:,1], r[:,3], edgecolors="k", facecolors='none')
plt.xlabel(r"$IPM_R$")
plt.ylabel(r"$IPM_L$")
# Out:
# Text(0,0.5,'$IPM_L$')

# %%
from importlib import reload
reload(ipm)
reload(ipm.scatter)

zmin,zmax = 0.,.2
norm = mpl.colors.Normalize(zmin, zmax)

e = 1000.
f = plt.figure(figsize=(17, 7))

l = -10000.
readings = ipm.differential_scattering(e, l=l, Z=None) 
f.suptitle(r"$|k_o|={}keV$".format(int(e/1000.)))
ax = f.add_subplot(121)
ax = ipm.plot_detector(readings, ax=ax, norm=norm)
ax.set_title("Backscatter")

l = 10000.
readings = ipm.differential_scattering(e, l=l, Z=None) 
ax = f.add_subplot(122)
e = 10000
ax = ipm.plot_detector(readings, ax=ax, norm=norm)
ax.set_title("Forward Scatter")
plt.tight_layout()

e = 10000.
f = plt.figure(figsize=(17, 7))

l = -10000.
readings = ipm.differential_scattering(e, l=l, Z=None) 
f.suptitle(r"$|k_o|={}keV$".format(int(e/1000.)))
ax = f.add_subplot(121)
ax = ipm.plot_detector(readings, ax=ax, norm=norm)
ax.set_title("Backscatter")

l = 10000.
readings = ipm.differential_scattering(e, l=l, Z=None) 
ax = f.add_subplot(122)
e = 10000
ax = ipm.plot_detector(readings, ax=ax, norm=norm)
ax.set_title("Forward Scatter")
plt.tight_layout()

# %%
from importlib import reload
reload(ipm)
reload(ipm.scatter)

xpos,ypos = 0., 2000.
#zmin,zmax = 0.,0.15
#norm = mpl.colors.Normalize(zmin, zmax)

e = 1000.
f = plt.figure(figsize=(17, 7))

l = -10000.
readings = ipm.differential_scattering(e, l=l, xpos=xpos, ypos=ypos) 
f.suptitle(r"$|k_o|={}keV$".format(int(e/1000.)))
ax = f.add_subplot(121)
ax = ipm.plot_detector(readings, ax=ax, xpos=xpos, ypos=ypos)
ax.set_title("Backscatter")

l = 10000.
readings = ipm.differential_scattering(e, l=l, xpos=xpos, ypos=ypos) 
ax = f.add_subplot(122)
e = 10000
ax = ipm.plot_detector(readings, ax=ax, xpos=xpos, ypos=ypos)
ax.set_title("Forward Scatter")
plt.tight_layout()

e = 10000.
f = plt.figure(figsize=(17, 7))

l = -10000.
readings = ipm.differential_scattering(e, l=l, xpos=xpos, ypos=ypos) 
f.suptitle(r"$|k_o|={}keV$".format(int(e/1000.)))
ax = f.add_subplot(121)
ax = ipm.plot_detector(readings, ax=ax, xpos=xpos, ypos=ypos)
ax.set_title("Backscatter")

l = 10000.
readings = ipm.differential_scattering(e, l=l, xpos=xpos, ypos=ypos) 
ax = f.add_subplot(122)
e = 10000
ax = ipm.plot_detector(readings, ax=ax, xpos=xpos, ypos=ypos)
ax.set_title("Forward Scatter")
plt.tight_layout()

# %%
e = 6000
e = 12600

f = plt.figure(figsize=(10,10))
theta = np.linspace(0., pi, 1000)

spar = 4.*scatter.differential_intensity(theta, 0., e, 7)*1e28
spar+= 3.*scatter.differential_intensity(theta, 0., e, 14)*1e28
spar = spar/7.
#plt.polar(pi-theta, spar, linestyle='--', c='k')
sperp = 4.*scatter.differential_intensity(theta, pi/2., e, 7)*1e28
sperp+= 3.*scatter.differential_intensity(theta, pi/2., e, 14)*1e28
sperp = sperp/7.
tot1 = spar + sperp
#plt.polar(pi-theta, sperp, linestyle='-.', c='k')
plt.polar(pi-theta, spar+sperp, linestyle='--', c='r', lw=3)


spar = 4.*scatter.differential_intensity(theta, 0., e, 7)*1e28
spar+= 3.*scatter.differential_intensity(theta, 0., e, 14)*1e28
spar = spar/7.
#plt.polar(pi-theta, spar, linestyle='--', c='k')
sperp = 4.*scatter.differential_intensity(theta, pi/2., e, 7)*1e28
sperp+= 3.*scatter.differential_intensity(theta, pi/2., e, 14)*1e28
sperp = sperp/7.
tot2 = spar + sperp
#plt.polar(pi-theta, sperp, linestyle='-.', c='k')
plt.polar(pi-theta, spar+sperp, c='b')


plt.legend([r"6 keV",
            r"12.6 keV"
           ])
plt.title(r"Silicon Nitride Scattering Cross Section")
plt.xlabel(r"$barn\ sr^{-1}\ atom^{-1}$")

ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)


plt.figure()
plt.polar(pi-theta, 100.*(tot1-tot2)/tot1, c='b')

plt.title(r"% Difference in scattering at 6 and 12.6 keV")
plt.xlabel(r"$barn\ sr^{-1}\ atom^{-1}$")

ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)

# %%
e = 10000

f = plt.figure(figsize=(10,10))
theta = np.linspace(0., pi, 1000)

spar = scatter.differential_intensity(theta, 0., e)*1e28
plt.polar(pi-theta, spar, linestyle='--', c='k')

sperp = scatter.differential_intensity(theta, pi/2., e)*1e28
plt.polar(pi-theta, sperp, linestyle='-.', c='k')

plt.polar(pi-theta, spar+sperp, c='k')

plt.legend([r"$(\frac {d\sigma} {d\Omega})_\parallel$",
            r"$(\frac {d\sigma} {d\Omega})_\bot$", 
            r"$(\frac {d\sigma} {d\Omega})_\parallel+ (\frac {d\sigma} {d\Omega})_\bot$", 
    ])
plt.title(r"$|k_o|={}keV$".format(int(e/1000.)))
plt.xlabel(r"$barn\ sr^{-1}\ electron^{-1}$")

ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)


e = 1000000

f = plt.figure(figsize=(10,10))
theta = np.linspace(0., pi, 1000)

spar = scatter.differential_intensity(theta, 0., e)*1e28
plt.polar(pi-theta, spar, linestyle='--', c='k')

sperp = scatter.differential_intensity(theta, pi/2., e)*1e28
plt.polar(pi-theta, sperp, linestyle='-.', c='k')

plt.polar(pi-theta, spar+sperp, c='k')

plt.legend([r"$(\frac {d\sigma} {d\Omega})_\parallel$",
            r"$(\frac {d\sigma} {d\Omega})_\bot$", 
            r"$(\frac {d\sigma} {d\Omega})_\parallel+ (\frac {d\sigma} {d\Omega})_\bot$", 
    ])
plt.title(r"$|k_o|={}keV$".format(int(e/1000.)))
plt.xlabel(r"$barn\ sr^{-1}\ electron^{-1}$")

ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)


e = 10000

f = plt.figure(figsize=(10,10))
theta = np.linspace(0., pi, 1000)

spar = 4.*scatter.differential_intensity(theta, 0., e, 7)*1e28
spar+= 3.*scatter.differential_intensity(theta, 0., e, 14)*1e28
spar = spar/7.
plt.polar(pi-theta, spar, linestyle='--', c='k')

sperp = 4.*scatter.differential_intensity(theta, pi/2., e, 7)*1e28
sperp+= 3.*scatter.differential_intensity(theta, pi/2., e, 14)*1e28
sperp = sperp/7.
plt.polar(pi-theta, sperp, linestyle='-.', c='k')

plt.polar(pi-theta, spar+sperp, c='k')

plt.legend([r"$(\frac {d\sigma} {d\Omega})_\parallel$",
            r"$(\frac {d\sigma} {d\Omega})_\bot$", 
            r"$(\frac {d\sigma} {d\Omega})_\parallel+ (\frac {d\sigma} {d\Omega})_\bot$", 
    ])
plt.title(r"$|k_o|={}keV$".format(int(e/1000.)))
plt.xlabel(r"$barn\ sr^{-1}\ atom^{-1}$")

ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)


e = 1000000

f = plt.figure(figsize=(10,10))
theta = np.linspace(0., pi, 1000)

spar = 4.*scatter.differential_intensity(theta, 0., e, 7)*1e28
spar+= 3.*scatter.differential_intensity(theta, 0., e, 14)*1e28
spar = spar/7.
plt.polar(pi-theta, spar, linestyle='--', c='k')

sperp = 4.*scatter.differential_intensity(theta, pi/2., e, 7)*1e28
sperp+= 3.*scatter.differential_intensity(theta, pi/2., e, 14)*1e28
sperp = sperp/7.
plt.polar(pi-theta, sperp, linestyle='-.', c='k')

plt.polar(pi-theta, spar+sperp, c='k')

plt.legend([r"$(\frac {d\sigma} {d\Omega})_\parallel$",
            r"$(\frac {d\sigma} {d\Omega})_\bot$", 
            r"$(\frac {d\sigma} {d\Omega})_\parallel+ (\frac {d\sigma} {d\Omega})_\bot$", 
    ])
plt.title(r"$|k_o|={}keV$".format(int(e/1000.)))
plt.xlabel(r"$barn\ sr^{-1}\ atom^{-1}$")

ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)

# %%
e = 10000

f = plt.figure(figsize=(10,10))
theta = np.linspace(0., pi, 1000)

spar = (3./7.)*scatter.differential_intensity(theta, 0., e, Z=14)*1e28  +\
       (4./7.)*scatter.differential_intensity(theta, 0., e, Z=7)*1e28
plt.polar(pi-theta, spar, linestyle='--', c='k')

sperp = (3./7.)*scatter.differential_intensity(theta, np.pi/2., e, Z=14)*1e28  +\
        (4./7.)*scatter.differential_intensity(theta, np.pi/2., e, Z=7)*1e28

plt.polar(pi-theta, sperp, linestyle='-.', c='k')

plt.polar(pi-theta, spar+sperp, c='k')

plt.legend([r"$(\frac {d\sigma} {d\Omega})_\parallel$",
            r"$(\frac {d\sigma} {d\Omega})_\bot$", 
            r"$(\frac {d\sigma} {d\Omega})_\parallel+ (\frac {d\sigma} {d\Omega})_\bot$", 
    ])
plt.title(r"""Differential Scattering Cross Section of $Si_3N_4$ 
$|k_o|={}keV$""".format(int(e/1000.)))
plt.xlabel(r"$barn\ sr^{-1}\ atom^{-1}$")

ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)

e = 10000

f = plt.figure(figsize=(10,10))
theta = np.linspace(0., pi, 1000)

spar = (1./7.)*scatter.differential_intensity(theta, 0., e, Z=7)*1e28
plt.polar(pi-theta, spar, linestyle='--', c='k')

sperp = (1./7.)*scatter.differential_intensity(theta, np.pi/2., e, Z=7)*1e28

plt.polar(pi-theta, sperp, linestyle='-.', c='k')

plt.polar(pi-theta, spar+sperp, c='k')

plt.legend([r"$(\frac {d\sigma} {d\Omega})_\parallel$",
            r"$(\frac {d\sigma} {d\Omega})_\bot$", 
            r"$(\frac {d\sigma} {d\Omega})_\parallel+ (\frac {d\sigma} {d\Omega})_\bot$", 
    ])
plt.title(r"""Differential Scattering Cross Section of N 
$|k_o|={}keV$""".format(int(e/1000.)))
plt.xlabel(r"$barn\ sr^{-1}\ electron^{-1}$")

ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)


f = plt.figure(figsize=(10,10))
theta = np.linspace(0., pi, 1000)

spar = scatter.differential_intensity(theta, 0., e)*1e28
plt.polar(pi-theta, spar, linestyle='--', c='k')

sperp = scatter.differential_intensity(theta, np.pi/2., e)*1e28

plt.polar(pi-theta, sperp, linestyle='-.', c='k')

plt.polar(pi-theta, spar+sperp, c='k')

plt.legend([r"$(\frac {d\sigma} {d\Omega})_\parallel$",
            r"$(\frac {d\sigma} {d\Omega})_\bot$", 
            r"$(\frac {d\sigma} {d\Omega})_\parallel+ (\frac {d\sigma} {d\Omega})_\bot$", 
    ])
plt.title(r"""Differential Scattering Cross Section of Free Electrons
$|k_o|={}keV$""".format(int(e/1000.)))
plt.xlabel(r"$barn\ sr^{-1}\ electron^{-1}$")

ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)




f = plt.figure(figsize=(10,10))
theta = np.linspace(0., pi, 1000)

Lambda = 1.
ff = scatter.formfactor[7](np.sin((theta/2.)/Lambda))
sf = scatter.scatteringfunction[7](np.sin((theta/2.)/Lambda))
plt.polar(theta, ff, c='k')
plt.polar(theta, sf, linestyle='--', c='k')
plt.legend(['Atomic Form Factor', 'Incoherent Scattering Function'])
plt.xlabel('Electrons')
plt.title("Scattering Parameters for Nitrogen")
ax = plt.gca()
ax.set_thetamin(0)
ax.set_thetamax(180)
